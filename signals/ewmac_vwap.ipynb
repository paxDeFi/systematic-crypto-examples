# %%
import sys

# Put your project root at the FRONT of sys.path
project_root = r"C:\Users\paxbr\OneDrive\Desktop\Coding\Quant\systematic-crypto-examples"
if project_root not in sys.path:
    sys.path.insert(0, project_root)

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from loader.load_ohlcv import load_ohlcv
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 12
#       9 import pandas as pd
#      10 import matplotlib.pyplot as plt
# ---> 12 from loader.load_ohlcv import load_ohlcv
#
# ModuleNotFoundError: No module named 'loader.load_ohlcv'

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 13
#      10 import pandas as pd
#      11 import matplotlib.pyplot as plt
# ---> 13 from loader.load_ohlcv import load_ohlcv
#
# ModuleNotFoundError: No module named 'loader.load_ohlcv'
